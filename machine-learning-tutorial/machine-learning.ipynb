# %%
# Course link on youtube https://www.youtube.com/watch?v=8jazNUpO3lQ&list=PLeo1K3hjS3uvCeTYTeyfe0-rN5r8zn9rw&index=3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("data/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline 
plt.xlabel("Area (sq ft)")
plt.ylabel("Price (US$)")
plt.scatter(df.area, df.price, marker='^', color='purple')
plt.plot(df.area, rg.predict(df[['area']]), color='red', linestyle='dashdot')

# %%
rg = linear_model.LinearRegression()
# Build linear regression model by mappiny area to price of known data points
rg.fit(df[["area"]], df.price)
# Out:
# LinearRegression()

# %%
rg.predict([[5000]])
# Out:
# /Users/clipset/projects/personal/scikit-learn/sklearn-env/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
# Coefficient or slope of the linear regression line
rg.coef_
# Out:
# array([135.78767123])

# %%
# Intercept or B value in y = mx + B equation
rg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
d = pd.read_csv("data/areas.csv")
d.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = rg.predict(d)
d["prices"] = p
d.to_csv("data/predicted_prices.csv", index=False)
